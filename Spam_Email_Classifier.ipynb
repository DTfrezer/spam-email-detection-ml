# %%
import pandas as pd

data = {
    "message": [
        "Congratulations! You won a free lottery ticket",
        "Hey, are we meeting tomorrow?",
        "Win cash now!!! Click here",
        "Please find the attached report",
        "Limited offer, claim your prize now",
        "Let’s have lunch today"
    ],
    "label": ["spam", "ham", "spam", "ham", "spam", "ham"]
}

df = pd.DataFrame(data)
df
# Out:
#                                           message label
# 0  Congratulations! You won a free lottery ticket  spam
# 1                   Hey, are we meeting tomorrow?   ham
# 2                      Win cash now!!! Click here  spam
# 3                 Please find the attached report   ham
# 4             Limited offer, claim your prize now  spam
# 5                          Let’s have lunch today   ham

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X = df["message"]
y = df["label"]

vectorizer = TfidfVectorizer(stop_words='english')
X_vectorized = vectorizer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y, test_size=0.3, random_state=42
)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

model = MultinomialNB()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
accuracy_score(y_test, predictions)
# Out:
# 0.5

# %%
test_msg = ["Free reward waiting for you"]
test_vec = vectorizer.transform(test_msg)

model.predict(test_vec)
# Out:
# array(['ham'], dtype='<U4')

# %%
['spam']
# Out:
# ['spam']

# %%
test_msg = ["Free reward waiting for you"]
test_vec = vectorizer.transform(test_msg)

model.predict(test_vec)
# Out:
# array(['ham'], dtype='<U4')

# %%
test_msg = ["Congratulations! You have won a free prize. Click now"]
test_vec = vectorizer.transform(test_msg)
model.predict(test_vec)
# Out:
# array(['spam'], dtype='<U4')

# %%
test_msg = ["Hi, please send me the project update by evening"]
test_vec = vectorizer.transform(test_msg)
model.predict(test_vec)
# Out:
# array(['ham'], dtype='<U4')
